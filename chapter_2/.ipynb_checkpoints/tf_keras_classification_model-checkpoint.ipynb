# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn 
import pandas as pd 
import os 
import sys
import time 
import tensorflow as tf 
from tensorflow import keras 

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.2.0
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)
# matplotlib 3.2.1
# numpy 1.18.5
# pandas 1.0.4
# sklearn 0.23.1
# tensorflow 2.2.0
# tensorflow.keras 2.3.0-tf

# %%
# 导入数据
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

# %%
print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
def show_single_image(img_arr):
    plt.imshow(img_arr, cmap='binary')
    plt.show()

show_single_image(x_train[0])

# %%
def show_imgs(n_rows, n_cols, x_data, y_data, class_names):
    assert len(x_data) == len(y_data)
    assert n_rows * n_cols < len(x_data)
    
    plt.figure(figsize= (n_cols * 1.4, n_rows * 1.6))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col
            plt.subplot(n_rows, n_cols, index+1)
            plt.imshow(x_data[index], cmap='binary', interpolation = 'nearest')
            plt.axis('off')
            plt.title(class_names[y_data[index]])
    plt.show()

class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 
              'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

show_imgs(5, 15, x_train, y_train, class_names)

# %%
# tf.keras.models.Sequential()

# model = keras.models.Sequential()
# model.add(keras.layers.Flatten(input_shape=[28, 28]))
# model.add(keras.layers.Dense(300, activation='relu'))
# model.add(keras.layers.Dense(100, activation='relu'))
# model.add(keras.layers.Dense(10, activation='softmax'))

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])


model.compile(loss='sparse_categorical_crossentropy', 
             optimizer='sgd',
             metrics = ['accuracy'])

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x15a3ceb70>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15a3ce320>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15a3cecc0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15a3cee10>]

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 300)               235500
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               30100
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_train, y_train, epochs=10, 
                 validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: nan - accuracy: 0.1006 - val_loss: nan - val_accuracy: 0.0914
# Epoch 2/10
# 1719/1719 [==============================] - 2s 959us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 3/10
# 1719/1719 [==============================] - 2s 965us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 4/10
# 1719/1719 [==============================] - 2s 967us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 5/10
# 1719/1719 [==============================] - 2s 959us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 6/10
# 1719/1719 [==============================] - 2s 967us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 7/10
# 1719/1719 [==============================] - 2s 976us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 9/10
# 1719/1719 [==============================] - 2s 992us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914
# Epoch 10/10
# 1719/1719 [==============================] - 2s 997us/step - loss: nan - accuracy: 0.1008 - val_loss: nan - val_accuracy: 0.0914

# %%
history.history
# Out:
# {'loss': [2.302649736404419,
#   2.302665948867798,
#   2.3026444911956787,
#   2.302652359008789,
#   2.3026509284973145,
#   2.3026375770568848,
#   2.3026552200317383,
#   2.3026371002197266,
#   2.3026435375213623,
#   2.302659273147583],
#  'accuracy': [0.09700000286102295,
#   0.09789090603590012,
#   0.09874545782804489,
#   0.09905454516410828,
#   0.09741818159818649,
#   0.09858182072639465,
#   0.09849090874195099,
#   0.09801818430423737,
#   0.09943636506795883,
#   0.0992727279663086],
#  'val_loss': [2.356391191482544,
#   2.3563568592071533,
#   2.3564565181732178,
#   2.356318712234497,
#   2.356351375579834,
#   2.3563003540039062,
#   2.3564112186431885,
#   2.356248378753662,
#   2.356177568435669,
#   2.356276035308838],
#  'val_accuracy': [0.09139999747276306,
#   0.09139999747276306,
#   0.09139999747276306,
#   0.09759999811649323,
#   0.09759999811649323,
#   0.10019999742507935,
#   0.09139999747276306,
#   0.09139999747276306,
#   0.1005999967455864,
#   0.09139999747276306]}

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %%
plot_learning_curves(history)
